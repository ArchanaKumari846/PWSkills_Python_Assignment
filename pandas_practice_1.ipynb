# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_csv("https://raw.githubusercontent.com/training-ml/Files/main/raw_data.csv")

# %%
df.head(10)
# Out:
#       id Employee Full Name         DOB                         email  gender  \
# 0  201.0        Salim Pound  02-12-2018           spound0@spotify.com    Male
# 1  202.0     Madelene Lutas   9/20/2018                mlutas1@si.edu  Female
# 2  203.0   Dolli Swanbourne  11/18/2018  dswanbourne2@istockphoto.com  Female
# 3  204.0    Graeme Croisier   9/29/2018                           NaN    Male
# 4  205.0     Jillana Physic   4/19/2018       jphysic4@yellowbook.com  Female
# 5  206.0    Anetta Yokelman   4/26/2018       ayokelman5@berkeley.edu  Female
# 6  207.0  Modesta Batterson   3/28/2018                           NaN  Female
# 7  208.0        Melina Boon  12/18/2017              mboon7@weibo.com    Male
# 8  209.0          Nomi Warn   1/16/2018              nwarn8@sogou.com  Female
# 9    NaN                NaN         NaN                           NaN     NaN
#
#      Company Country           Income.1  Income.2
# 0     Google   India  $46476.6380809961     529.0
# 1     Amazon     USA  $54174.6879482406     720.0
# 2      Intel     UAS                NaN     234.0
# 3  Accenture  Canada  $46784.6308786279     657.0
# 4  Accenture     NaN  $57486.4955595568    1947.0
# 5      Intel   India                  $     952.0
# 6      Intel   India                NaN      32.0
# 7     Amazon   India                NaN    1901.0
# 8     Amazon     UAS  $28602.4353770562       NaN
# 9        NaN     NaN                NaN       NaN

# %%
df.columns
# Out:
# Index(['id', 'Employee Full Name', 'DOB', 'email', 'gender', 'Company',
#        'Country', 'Income.1', 'Income.2'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# id                    1
# Employee Full Name    1
# DOB                   1
# email                 3
# gender                1
# Company               1
# Country               3
# Income.1              5
# Income.2              3
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  19 non-null     float64
#  1   Employee Full Name  19 non-null     object
#  2   DOB                 19 non-null     object
#  3   email               17 non-null     object
#  4   gender              19 non-null     object
#  5   Company             19 non-null     object
#  6   Country             17 non-null     object
#  7   Income.1            15 non-null     object
#  8   Income.2            17 non-null     float64
# dtypes: float64(2), object(7)
# memory usage: 1.5+ KB

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# dtype: bool

# %%
df.shape
# Out:
# (20, 9)

# %%
df.iloc[9]=[210,'Jim Carry', '1/1/1970', 'jim.carry@gmail.com', 'Male', 'Amazon', 'USA', 12349.556, 2365]

# %%
df.head(10)
# Out:
#       id Employee Full Name         DOB                         email  gender  \
# 0  201.0        Salim Pound  02-12-2018           spound0@spotify.com    Male
# 1  202.0     Madelene Lutas   9/20/2018                mlutas1@si.edu  Female
# 2  203.0   Dolli Swanbourne  11/18/2018  dswanbourne2@istockphoto.com  Female
# 3  204.0    Graeme Croisier   9/29/2018                           NaN    Male
# 4  205.0     Jillana Physic   4/19/2018       jphysic4@yellowbook.com  Female
# 5  206.0    Anetta Yokelman   4/26/2018       ayokelman5@berkeley.edu  Female
# 6  207.0  Modesta Batterson   3/28/2018                           NaN  Female
# 7  208.0        Melina Boon  12/18/2017              mboon7@weibo.com    Male
# 8  209.0          Nomi Warn   1/16/2018              nwarn8@sogou.com  Female
# 9  210.0          Jim Carry    1/1/1970           jim.carry@gmail.com    Male
#
#      Company Country           Income.1  Income.2
# 0     Google   India  $46476.6380809961     529.0
# 1     Amazon     USA  $54174.6879482406     720.0
# 2      Intel     UAS                NaN     234.0
# 3  Accenture  Canada  $46784.6308786279     657.0
# 4  Accenture     NaN  $57486.4955595568    1947.0
# 5      Intel   India                  $     952.0
# 6      Intel   India                NaN      32.0
# 7     Amazon   India                NaN    1901.0
# 8     Amazon     UAS  $28602.4353770562       NaN
# 9     Amazon     USA          12349.556    2365.0

# %%
df.at[3,'email']='graeme.croisier@gmail.com'
df.at[6,'email']='modesta.batterson@gmail.com'

# %%
df.head(10)
# Out:
#       id Employee Full Name         DOB                         email  gender  \
# 0  201.0        Salim Pound  02-12-2018           spound0@spotify.com    Male
# 1  202.0     Madelene Lutas   9/20/2018                mlutas1@si.edu  Female
# 2  203.0   Dolli Swanbourne  11/18/2018  dswanbourne2@istockphoto.com  Female
# 3  204.0    Graeme Croisier   9/29/2018     graeme.croisier@gmail.com    Male
# 4  205.0     Jillana Physic   4/19/2018       jphysic4@yellowbook.com  Female
# 5  206.0    Anetta Yokelman   4/26/2018       ayokelman5@berkeley.edu  Female
# 6  207.0  Modesta Batterson   3/28/2018   modesta.batterson@gmail.com  Female
# 7  208.0        Melina Boon  12/18/2017              mboon7@weibo.com    Male
# 8  209.0          Nomi Warn   1/16/2018              nwarn8@sogou.com  Female
# 9  210.0          Jim Carry    1/1/1970           jim.carry@gmail.com    Male
#
#      Company Country           Income.1  Income.2
# 0     Google   India  $46476.6380809961     529.0
# 1     Amazon     USA  $54174.6879482406     720.0
# 2      Intel     UAS                NaN     234.0
# 3  Accenture  Canada  $46784.6308786279     657.0
# 4  Accenture     NaN  $57486.4955595568    1947.0
# 5      Intel   India                  $     952.0
# 6      Intel   India                NaN      32.0
# 7     Amazon   India                NaN    1901.0
# 8     Amazon     UAS  $28602.4353770562       NaN
# 9     Amazon     USA          12349.556    2365.0

# %%
df['Country']= df['Country'].fillna(value=0)

# %%
df.head(10)
# Out:
#       id Employee Full Name         DOB                         email  gender  \
# 0  201.0        Salim Pound  02-12-2018           spound0@spotify.com    Male
# 1  202.0     Madelene Lutas   9/20/2018                mlutas1@si.edu  Female
# 2  203.0   Dolli Swanbourne  11/18/2018  dswanbourne2@istockphoto.com  Female
# 3  204.0    Graeme Croisier   9/29/2018     graeme.croisier@gmail.com    Male
# 4  205.0     Jillana Physic   4/19/2018       jphysic4@yellowbook.com  Female
# 5  206.0    Anetta Yokelman   4/26/2018       ayokelman5@berkeley.edu  Female
# 6  207.0  Modesta Batterson   3/28/2018   modesta.batterson@gmail.com  Female
# 7  208.0        Melina Boon  12/18/2017              mboon7@weibo.com    Male
# 8  209.0          Nomi Warn   1/16/2018              nwarn8@sogou.com  Female
# 9  210.0          Jim Carry    1/1/1970           jim.carry@gmail.com    Male
#
#      Company Country           Income.1  Income.2
# 0     Google   India  $46476.6380809961     529.0
# 1     Amazon     USA  $54174.6879482406     720.0
# 2      Intel     UAS                NaN     234.0
# 3  Accenture  Canada  $46784.6308786279     657.0
# 4  Accenture       0  $57486.4955595568    1947.0
# 5      Intel   India                  $     952.0
# 6      Intel   India                NaN      32.0
# 7     Amazon   India                NaN    1901.0
# 8     Amazon     UAS  $28602.4353770562       NaN
# 9     Amazon     USA          12349.556    2365.0
